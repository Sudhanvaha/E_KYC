# %%
from paddleocr import PaddleOCR,draw_ocr
ocr=PaddleOCR(use_angle_cls=True,use_gpu=False)
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/chinese/ch_PP-OCRv4_det_infer.tar to C:\Users\sudha/.paddleocr/whl\det\ch\ch_PP-OCRv4_det_infer\ch_PP-OCRv4_det_infer.tar
# 100%|██████████| 4.89M/4.89M [02:01<00:00, 40.2kiB/s]
# download https://paddleocr.bj.bcebos.com/PP-OCRv4/chinese/ch_PP-OCRv4_rec_infer.tar to C:\Users\sudha/.paddleocr/whl\rec\ch\ch_PP-OCRv4_rec_infer\ch_PP-OCRv4_rec_infer.tar
# 100%|██████████| 11.0M/11.0M [03:21<00:00, 54.4kiB/s]
# download https://paddleocr.bj.bcebos.com/dygraph_v2.0/ch/ch_ppocr_mobile_v2.0_cls_infer.tar to C:\Users\sudha/.paddleocr/whl\cls\ch_ppocr_mobile_v2.0_cls_infer\ch_ppocr_mobile_v2.0_cls_infer.tar
# 100%|██████████| 2.19M/2.19M [00:03<00:00, 564kiB/s]
# ...

# %%
import cv2
img_path=r"C:\Users\sudha\e_kyc\day1\contour_id.png"
result=ocr.ocr(img_path)
image=cv2.imread(img_path)
# Out:
# [2024/07/21 21:12:38] ppocr DEBUG: dt_boxes num : 8, elapsed : 0.8606827259063721
# [2024/07/21 21:12:39] ppocr DEBUG: cls num  : 8, elapsed : 0.3010573387145996
# [2024/07/21 21:12:39] ppocr DEBUG: rec_res num  : 8, elapsed : 0.6851387023925781

# %%
result
# Out:
# [[[[[194.0, 62.0], [355.0, 58.0], [355.0, 78.0], [194.0, 81.0]],
#    ('GOVERNMENT OFINDY', 0.924424946308136)],
#   [[[174.0, 133.0], [343.0, 130.0], [343.0, 147.0], [174.0, 150.0]],
#    ('NIRUPMAPUSHKARNA', 0.9914379119873047)],
#   [[[174.0, 154.0], [310.0, 151.0], [311.0, 171.0], [174.0, 175.0]],
#    ('a/YoB:1951', 0.8369280695915222)],
#   [[[178.0, 181.0], [287.0, 181.0], [287.0, 201.0], [178.0, 201.0]],
#    ('HfeaT Female', 0.7272756099700928)],
#   [[[192.0, 286.0], [331.0, 283.0], [331.0, 303.0], [192.0, 307.0]],
#    ('871608138875', 0.998845636844635)]]]

# %%
import matplotlib.pyplot as plt

# %%
def show_ocr(ocr,img_path,font):

    result=ocr.ocr(img_path)

    image=cv2.imread(img_path)

    boxes=[line[0] for line in result[0]]
    txts=[line[1][0] for line in result[0]]
    scores=[line[1][1] for line in result[0]]

    im_show =draw_ocr(image,boxes,txts,scores,font_path=font)

    img=cv2.cvtColor(im_show,cv2.COLOR_BGR2RGB)
    plt.imshow(img)
    plt.axis('off')

# %%
show_ocr(ocr, img_path="C:\\Users\\sudha\\e_kyc\\day1\\bibek.png", font="C:\\Windows\\Fonts\\Arial.ttf")
# Out:
# [2024/07/21 21:30:42] ppocr DEBUG: dt_boxes num : 14, elapsed : 0.5433375835418701
# [2024/07/21 21:30:42] ppocr DEBUG: cls num  : 14, elapsed : 0.06424069404602051
# [2024/07/21 21:30:42] ppocr DEBUG: rec_res num  : 14, elapsed : 0.7004680633544922

# %%
font_path = "C:\\Users\\sudha\\e_kyc\\data\\01_raw_data\\simfang.ttf"
